# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import warnings
warnings.filterwarnings("ignore")
# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../Starter_Code/output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       jamestown  42.0970  -79.2353     -1.66        72         100
# 1        1         huarmey -10.0681  -78.1522     23.73        72          87
# 2        2    norman wells  65.2820 -126.8329    -19.98        77         100
# 3        3  harbour breton  47.4833  -55.7983      2.23        93         100
# 4        4     antofagasta -23.6500  -70.4000     23.60        68          37
#
#    Wind Speed Country        Date
# 0        5.14      US  1674497516
# 1        3.67      PE  1674497593
# 2        1.03      CA  1674497593
# 3        8.46      CA  1674497593
# 4        4.14      CL  1674497580

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_humidity_map = city_data_df.hvplot.points("Lng", "Lat", geo=True, tiles= "OSM", frame_width=800, frame_height=600, size="Humidity", color="Humidity")


# Display the map
city_humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

# Ideal weather condition : 
# Max tempreture must be lower than 25°C and higher than 10°C
# Wind Speed les than 10 mph
# Cloudiness = 0

narrow_city_df = city_data_df.copy()
narrow_city_df = narrow_city_df[narrow_city_df["Max Temp"]>=10]
narrow_city_df = narrow_city_df[narrow_city_df["Max Temp"]<=30]
narrow_city_df = narrow_city_df[narrow_city_df["Wind Speed"]<15]
narrow_city_df = narrow_city_df[narrow_city_df["Cloudiness"]==0]
narrow_city_df = narrow_city_df.reset_index(drop = True)
# Drop any rows with null values
narrow_city_df = narrow_city_df.dropna()

# Display sample data
narrow_city_df
# Out:
#     City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0        32        busselton -33.6500  115.3333     18.57        78
# 1        86            pisco -13.7000  -76.2167     27.03        57
# 2        87         ajdabiya  30.7554   20.2263     14.79        36
# 3        88              gat  31.6100   34.7642     18.00        69
# 4        90            perth -31.9333  115.8333     23.28        92
# 5       131      keti bandar  24.1447   67.4497     17.97        23
# 6       151            kapaa  22.0752 -159.3190     21.18        90
# 7       156        porbandar  21.6422   69.6093     18.11        45
# 8       162        esperance -33.8667  121.9000     17.91        66
# 9       171    mar del plata -38.0023  -57.5575     27.13        60
# 10      185        galveston  29.3669  -94.9669     13.97        61
# 11      189  lazaro cardenas  17.9583 -102.2000     28.02        49
# 12      209         hurghada  27.2574   33.8129     17.89        58
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
hotel_df = narrow_city_df[["City","Country","Lat","Lng","Humidity"]].copy()

hotel_df
# Out:
#                City Country      Lat       Lng  Humidity
# 0         busselton      AU -33.6500  115.3333        78
# 1             pisco      PE -13.7000  -76.2167        57
# 2          ajdabiya      LY  30.7554   20.2263        36
# 3               gat      IL  31.6100   34.7642        69
# 4             perth      AU -31.9333  115.8333        92
# 5       keti bandar      PK  24.1447   67.4497        23
# 6             kapaa      US  22.0752 -159.3190        90
# 7         porbandar      IN  21.6422   69.6093        45
# 8         esperance      AU -33.8667  121.9000        66
# 9     mar del plata      AR -38.0023  -57.5575        60
# 10        galveston      US  29.3669  -94.9669        61
# 11  lazaro cardenas      MX  17.9583 -102.2000        49
# 12         hurghada      EG  27.2574   33.8129        58
# 13        taoudenni      ML  22.6783   -3.9836        15
# 14           laguna      US  38.4210 -121.4238        46
# ...

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrow_city_df[["City","Country","Lat","Lng","Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]= ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 0         busselton      AU -33.6500  115.3333        78
# 1             pisco      PE -13.7000  -76.2167        57
# 2          ajdabiya      LY  30.7554   20.2263        36
# 3               gat      IL  31.6100   34.7642        69
# 4             perth      AU -31.9333  115.8333        92
# 5       keti bandar      PK  24.1447   67.4497        23
# 6             kapaa      US  22.0752 -159.3190        90
# 7         porbandar      IN  21.6422   69.6093        45
# 8         esperance      AU -33.8667  121.9000        66
# 9     mar del plata      AR -38.0023  -57.5575        60
# 10        galveston      US  29.3669  -94.9669        61
# 11  lazaro cardenas      MX  17.9583 -102.2000        49
# 12         hurghada      EG  27.2574   33.8129        58
# 13        taoudenni      ML  22.6783   -3.9836        15
# 14           laguna      US  38.4210 -121.4238        46
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "radius": radius,
    "apiKey" : geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat=hotel_df.loc[index, "Lat"]
    lng=hotel_df.loc[index, "Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url,params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# busselton - nearest hotel: Broadwater Beach Resort
# pisco - nearest hotel: La Portada
# ajdabiya - nearest hotel: فندق المدينة
# gat - nearest hotel: No hotel found
# perth - nearest hotel: Oxford Hotel
# keti bandar - nearest hotel: No hotel found
# kapaa - nearest hotel: Pono Kai Resort
# porbandar - nearest hotel: Toran Tourist Bungalow
# esperance - nearest hotel: Hospitality
# mar del plata - nearest hotel: Nuevo Ostende
# galveston - nearest hotel: Comfort Inn & Suites Texas City
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# hurghada - nearest hotel: Sea Horse Hotel
# taoudenni - nearest hotel: No hotel found
# laguna - nearest hotel: Holiday Inn Express & Suites
# abha - nearest hotel: SAHAB
# rawson - nearest hotel: Hotel Deportivo
# panguipulli - nearest hotel: Cabañas Villa Los Encinos
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# half moon bay - nearest hotel: Half Moon Bay Inn
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng","Lat", geo=True, tiles= "OSM", frame_width=800, frame_height=600, color="Hotel Name",hover_cols=["Country"])

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Hotel Name,Country)
